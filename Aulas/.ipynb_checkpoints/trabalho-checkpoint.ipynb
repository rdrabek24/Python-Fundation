# %%
1 + 2
# Out:
# 3

# %%
print('Olá Mundo')
# Out:
# Olá Mundo

# %%
import pandas as pd

# %%
df = pd.read_csv('BRAZIL.csv', delimiter=';', encoding='UTF-8')

# %%
df.head()
# Out:
#                   CITY    Cars  Motorcycles
# 0      Abadia De Goiás  2158.0       1246.0
# 1  Abadia Dos Dourados  2227.0       1142.0
# 2            Abadiânia  2838.0       1426.0
# 3               Abaeté  6928.0       2953.0
# 4           Abaetetuba  5277.0      25661.0

# %%
df.shape
# Out:
# (5573, 81)

# %%
df['CITY']
# Out:
# 0           Abadia De Goiás
# 1       Abadia Dos Dourados
# 2                 Abadiânia
# 3                    Abaeté
# 4                Abaetetuba
#                ...
# 5568            Xique-Xique
# 5569                 Zabelê
# 5570               Zacarias
# 5571                Zé Doca
# 5572                 Zortéa
# Name: CITY, Length: 5573, dtype: object

# %%
df["CarsXCity"] = str(df["Cars"]) + df["CITY"]

# %%
df.head()
# Out:
#                   CITY STATE  CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  \
# 0      Abadia De Goiás    GO        0        6876.0             6876.0
# 1  Abadia Dos Dourados    MG        0        6704.0             6704.0
# 2            Abadiânia    GO        0       15757.0            15609.0
# 3               Abaeté    MG        0       22690.0            22690.0
# 4           Abaetetuba    PA        0      141100.0           141040.0
#
#    IBGE_RES_POP_ESTR  IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL  IBGE_POP  ...  \
# 0                0.0   2137.0         1546.0          591.0    5300.0  ...
# 1                0.0   2328.0         1481.0          847.0    4154.0  ...
# 2              148.0   4655.0         3233.0         1422.0   10656.0  ...
# 3                0.0   7694.0         6667.0         1027.0   18464.0  ...
# 4               60.0  31061.0        19057.0        12004.0   82956.0  ...
#
#     Pr_Assets    Pu_Assets    Cars  Motorcycles  Wheeled_tractor  UBER  MAC  \
# ...

# %%
df.head()
# Out:
#                   CITY STATE  CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  \
# 0      Abadia De Goiás    GO        0        6876.0             6876.0
# 1  Abadia Dos Dourados    MG        0        6704.0             6704.0
# 2            Abadiânia    GO        0       15757.0            15609.0
# 3               Abaeté    MG        0       22690.0            22690.0
# 4           Abaetetuba    PA        0      141100.0           141040.0
#
#    IBGE_RES_POP_ESTR  IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL  IBGE_POP  ...  \
# 0                0.0   2137.0         1546.0          591.0    5300.0  ...
# 1                0.0   2328.0         1481.0          847.0    4154.0  ...
# 2              148.0   4655.0         3233.0         1422.0   10656.0  ...
# 3                0.0   7694.0         6667.0         1027.0   18464.0  ...
# 4               60.0  31061.0        19057.0        12004.0   82956.0  ...
#
#    Pu_Bank   Pr_Assets    Pu_Assets    Cars  Motorcycles  Wheeled_tractor  \
# ...

# %%
df.iLoc[1,0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-800c91f3c58b> in <module>
# ----> 1 df.Loc[1,0]
#
# ~/Desktop/Python_fundamentals/exercicios/venv/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Loc'
